# %%
# latex stuff for colab
system('pip install folium==0.2.1', intern=TRUE)
system('pip install pdflatex', intern=TRUE)
system('sudo apt-get install texlive-latex-recommended', intern=TRUE)
system('sudo apt install texlive-latex-extra', intern=TRUE)
system('sudo apt install dvipng', intern=TRUE)
# Out:
#  [1] "Collecting folium==0.2.1"
#  [2] "  Downloading https://files.pythonhosted.org/packages/72/dd/75ced7437bfa7cb9a88b96ee0177953062803c3b4cde411a97d98c35adaf/folium-0.2.1.tar.gz (69kB)"
#  [3] "Requirement already satisfied: Jinja2 in /usr/local/lib/python2.7/dist-packages (from folium==0.2.1) (2.10.1)"
#  [4] "Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python2.7/dist-packages (from Jinja2->folium==0.2.1) (1.1.1)"
#  [5] "Building wheels for collected packages: folium"
#  [6] "  Building wheel for folium (setup.py): started"
#  [7] "  Building wheel for folium (setup.py): finished with status 'done'"
#  [8] "  Created wheel for folium: filename=folium-0.2.1-cp27-none-any.whl size=79990 sha256=774993eb82411f9a13f4f3972b8cb602ed3b250e6e086c66b80df6cac5ee34bf"
#  [9] "  Stored in directory: /root/.cache/pip/wheels/b8/09/f0/52d2ef419c2aaf4fb149f92a33e0008bdce7ae816f0dd8f0c5"
# [10] "Successfully built folium"
# [11] "Installing collected packages: folium"
# [12] "  Found existing installation: folium 0.8.3"
# [13] "    Uninstalling folium-0.8.3:"
# [14] "      Successfully uninstalled folium-0.8.3"
# [15] "Successfully installed folium-0.2.1"
# Warning message in system("pip install pdflatex", intern = TRUE):
# “running command 'pip install pdflatex' had status 1”
# character(0)
# attr(,"status")
# [1] 1
# attr(,"errmsg")
# [1] "Resource temporarily unavailable"
#   [1] "Reading package lists..."
#   [2] "Building dependency tree..."
#   [3] "Reading state information..."
#   [4] "The following package was automatically installed and is no longer required:"
#   [5] "  libnvidia-common-460"
#   [6] "Use 'sudo apt autoremove' to remove it."
#   [7] "The following additional packages will be installed:"
#   [8] "  fonts-droid-fallback fonts-lmodern fonts-noto-mono libcupsfilters1"
#   [9] "  libcupsimage2 libgs9 libgs9-common libijs-0.35 libjbig2dec0 libkpathsea6"
#  [10] "  libpotrace0 libptexenc1 libsynctex1 libtexlua52 libtexluajit2 libzzip-0-13"
#  [11] "  lmodern poppler-data t1utils tex-common texlive-base texlive-binaries"
#  [12] "  texlive-latex-base"
#  [13] "Suggested packages:"
#  [14] "  fonts-noto poppler-utils ghostscript fonts-japanese-mincho"
#  [15] "  | fonts-ipafont-mincho fonts-japanese-gothic | fonts-ipafont-gothic"
#  [16] "  fonts-arphic-ukai fonts-arphic-uming fonts-nanum debhelper gv"
#  [17] "  | postscript-viewer perl-tk xpdf-reader | pdf-viewer texlive-latex-base-doc"
#  [18] "  texlive-latex-recommended-doc texlive-pstricks"
#  [19] "The following NEW packages will be installed:"
#  [20] "  fonts-droid-fallback fonts-lmodern fonts-noto-mono libcupsfilters1"
#  [21] "  libcupsimage2 libgs9 libgs9-common libijs-0.35 libjbig2dec0 libkpathsea6"
#  [22] "  libpotrace0 libptexenc1 libsynctex1 libtexlua52 libtexluajit2 libzzip-0-13"
#  [23] "  lmodern poppler-data t1utils tex-common texlive-base texlive-binaries"
#  [24] "  texlive-latex-base texlive-latex-recommended"
#  [25] "0 upgraded, 24 newly installed, 0 to remove and 40 not upgraded."
#  [26] "Need to get 68.4 MB of archives."
#  [27] "After this operation, 223 MB of additional disk space will be used."
#  [28] "Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1 [1,805 kB]"
#  [29] "Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 poppler-data all 0.4.8-2 [1,479 kB]"
#  [30] "Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 tex-common all 6.09 [33.0 kB]"
#  [31] "Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-lmodern all 2.004.5-3 [4,551 kB]"
#  [32] "Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-noto-mono all 20171026-2 [75.5 kB]"
#  [33] "Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcupsfilters1 amd64 1.20.2-0ubuntu3.1 [108 kB]"
#  [34] "Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcupsimage2 amd64 2.2.7-1ubuntu2.8 [18.6 kB]"
#  [35] "Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 libijs-0.35 amd64 0.35-13 [15.5 kB]"
#  [36] "Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjbig2dec0 amd64 0.13-6 [55.9 kB]"
#  [37] "Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgs9-common all 9.26~dfsg+0-0ubuntu0.18.04.14 [5,092 kB]"
#  [38] "Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgs9 amd64 9.26~dfsg+0-0ubuntu0.18.04.14 [2,265 kB]"
#  [39] "Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libkpathsea6 amd64 2017.20170613.44572-8ubuntu0.1 [54.9 kB]"
#  [40] "Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpotrace0 amd64 1.14-2 [17.4 kB]"
#  [41] "Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libptexenc1 amd64 2017.20170613.44572-8ubuntu0.1 [34.5 kB]"
#  [42] "Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsynctex1 amd64 2017.20170613.44572-8ubuntu0.1 [41.4 kB]"
#  [43] "Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libtexlua52 amd64 2017.20170613.44572-8ubuntu0.1 [91.2 kB]"
#  [44] "Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libtexluajit2 amd64 2017.20170613.44572-8ubuntu0.1 [230 kB]"
#  [45] "Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libzzip-0-13 amd64 0.13.62-3.1ubuntu0.18.04.1 [26.0 kB]"
#  [46] "Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 lmodern all 2.004.5-3 [9,631 kB]"
#  [47] "Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 t1utils amd64 1.41-2 [56.0 kB]"
#  [48] "Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 texlive-binaries amd64 2017.20170613.44572-8ubuntu0.1 [8,179 kB]"
#  [49] "Get:22 http://archive.ubuntu.com/ubuntu bionic/main amd64 texlive-base all 2017.20180305-1 [18.7 MB]"
#  [50] "Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 texlive-latex-base all 2017.20180305-1 [951 kB]"
#  [51] "Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 texlive-latex-recommended all 2017.20180305-1 [14.9 MB]"
#  [52] "Fetched 68.4 MB in 8s (8,540 kB/s)"
#  [53] "Selecting previously unselected package fonts-droid-fallback.\r"
#  [54] "(Reading database ... \r(Reading database ... 5%\r(Reading database ... 10%\r(Reading database ... 15%\r(Reading database ... 20%\r(Reading database ... 25%\r(Reading database ... 30%\r(Reading database ... 35%\r(Reading database ... 40%\r(Reading database ... 45%\r(Reading database ... 50%\r(Reading database ... 55%\r(Reading database ... 60%\r(Reading database ... 65%\r(Reading database ... 70%\r(Reading database ... 75%\r(Reading database ... 80%\r(Reading database ... 85%\r(Reading database ... 90%\r(Reading database ... 95%\r(Reading database ... 100%\r(Reading database ... 148489 files and directories currently installed.)\r"
#  [55] "Preparing to unpack .../00-fonts-droid-fallback_1%3a6.0.1r16-1.1_all.deb ...\r"
#  [56] "Unpacking fonts-droid-fallback (1:6.0.1r16-1.1) ...\r"
#  [57] "Selecting previously unselected package poppler-data.\r"
#  [58] "Preparing to unpack .../01-poppler-data_0.4.8-2_all.deb ...\r"
#  [59] "Unpacking poppler-data (0.4.8-2) ...\r"
#  [60] "Selecting previously unselected package tex-common.\r"
#  [61] "Preparing to unpack .../02-tex-common_6.09_all.deb ...\r"
#  [62] "Unpacking tex-common (6.09) ...\r"
#  [63] "Selecting previously unselected package fonts-lmodern.\r"
#  [64] "Preparing to unpack .../03-fonts-lmodern_2.004.5-3_all.deb ...\r"
#  [65] "Unpacking fonts-lmodern (2.004.5-3) ...\r"
#  [66] "Selecting previously unselected package fonts-noto-mono.\r"
#  [67] "Preparing to unpack .../04-fonts-noto-mono_20171026-2_all.deb ...\r"
#  [68] "Unpacking fonts-noto-mono (20171026-2) ...\r"
#  [69] "Selecting previously unselected package libcupsfilters1:amd64.\r"
#  [70] "Preparing to unpack .../05-libcupsfilters1_1.20.2-0ubuntu3.1_amd64.deb ...\r"
# ...
# [10] "  ghostscript-x"
# [11] "The following NEW packages will be installed:"
# [12] "  dvipng ghostscript gsfonts"
# [13] "0 upgraded, 3 newly installed, 0 to remove and 40 not upgraded."
# [14] "Need to get 3,250 kB of archives."
# [15] "After this operation, 4,947 kB of additional disk space will be used."
# [16] "Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ghostscript amd64 9.26~dfsg+0-0ubuntu0.18.04.14 [51.3 kB]"
# [17] "Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dvipng amd64 1.15-1 [78.2 kB]"
# [18] "Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 gsfonts all 1:8.11+urwcyr1.0.7~pre44-4.4 [3,120 kB]"
# [19] "Fetched 3,250 kB in 2s (1,323 kB/s)"
# [20] "Selecting previously unselected package ghostscript.\r"
# [21] "(Reading database ... \r(Reading database ... 5%\r(Reading database ... 10%\r(Reading database ... 15%\r(Reading database ... 20%\r(Reading database ... 25%\r(Reading database ... 30%\r(Reading database ... 35%\r(Reading database ... 40%\r(Reading database ... 45%\r(Reading database ... 50%\r(Reading database ... 55%\r(Reading database ... 60%\r(Reading database ... 65%\r(Reading database ... 70%\r(Reading database ... 75%\r(Reading database ... 80%\r(Reading database ... 85%\r(Reading database ... 90%\r(Reading database ... 95%\r(Reading database ... 100%\r(Reading database ... 174174 files and directories currently installed.)\r"
# [22] "Preparing to unpack .../ghostscript_9.26~dfsg+0-0ubuntu0.18.04.14_amd64.deb ...\r"
# [23] "Unpacking ghostscript (9.26~dfsg+0-0ubuntu0.18.04.14) ...\r"
# [24] "Selecting previously unselected package dvipng.\r"
# [25] "Preparing to unpack .../dvipng_1.15-1_amd64.deb ...\r"
# [26] "Unpacking dvipng (1.15-1) ...\r"
# [27] "Selecting previously unselected package gsfonts.\r"
# [28] "Preparing to unpack .../gsfonts_1%3a8.11+urwcyr1.0.7~pre44-4.4_all.deb ...\r"
# [29] "Unpacking gsfonts (1:8.11+urwcyr1.0.7~pre44-4.4) ...\r"
# [30] "Setting up gsfonts (1:8.11+urwcyr1.0.7~pre44-4.4) ...\r"
# [31] "Setting up ghostscript (9.26~dfsg+0-0ubuntu0.18.04.14) ...\r"
# [32] "Setting up dvipng (1.15-1) ...\r"
# [33] "Processing triggers for fontconfig (2.12.6-0ubuntu2) ...\r"
# [34] "Processing triggers for man-db (2.8.3-2ubuntu0.1) ...\r"

# %%
install.packages("tidyverse")
install.packages("tibble")
install.packages("magrittr")
install.packages("dplyr")
install.packages("reshape2")
install.packages("latex2exp")
install.packages("gridExtra")
install.packages("tikzDevice")
install.packages("truncnorm")
install.packages("igraph")
install.packages('pracma')
install.packages('akima')
install.packages('rgl')

## Load required packages 
library(tidyverse)
library(tibble)
library(magrittr)
library(dplyr)
library(reshape2)
library(latex2exp)
library(gridExtra)
library(tikzDevice)
library(pracma)
library(akima)
library(rgl)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘plyr’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘filehash’, ‘png’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘sp’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘lazyeval’, ‘htmlwidgets’, ‘crosstalk’
#
#
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.4     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   2.0.1     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘magrittr’
#
#
# The following object is masked from ‘package:purrr’:
#
#     set_names
#
#
# The following object is masked from ‘package:tidyr’:
#
#     extract
#
#
#
# Attaching package: ‘reshape2’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths
#
#
#
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
#
# Attaching package: ‘pracma’
#
#
# The following objects are masked from ‘package:magrittr’:
#
#     and, mod, or
#
#
# The following object is masked from ‘package:purrr’:
#
#     cross
#
#
# Warning message in rgl.init(initValue, onlyNULL):
# “RGL: unable to open X11 display”
# Warning message:
# “'rgl.init' failed, running with 'rgl.useNULL = TRUE'.”

# %%
# load support files
source("lemke-howson.R")
source("build_functions.R")
# Out:
# Loading required package: MASS
#
#
# Attaching package: ‘MASS’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     select
#
#
# Loading required package: truncnorm
#
# Loading required package: igraph
#
#
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     as_data_frame, groups, union
#
#
# The following objects are masked from ‘package:purrr’:
#
#     compose, simplify
#
#
# The following object is masked from ‘package:tidyr’:
#
#     crossing
#
#
# The following object is masked from ‘package:tibble’:
#
#     as_data_frame
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union

# %%
# getOption("tikzLatex")
options("tikzLatex"='/usr/bin/pdflatex')

options(repr.plot.width=16, repr.plot.height=7)  #to set graph size
par(mar=c(5, 5, 4, 2), cex=1.5)#, mfrow= c(1,2))

# %% [markdown]
# ## Example of dynamical pruning under Lotka-Volterra dynamics

# %%
## Set parameter values
n <- 1000 ## number of species in the original community
params_interactions <- list(build.structure = build.no.structure, ## completely filled matrix
                            build.matrix = build.normal,          ## normal distribution sampling for Aij 
                            u = 0,                                ## mean of interactions
                            d = -1,                               ## original mean diagonal 
                            sd = 1                                ## standard deviation of interactions
                            )
params_growth_rates <- list(u = 0,                   ## mean of growth rates
                            sd = 1                   ## sd of growth rates   
                            )
A <- build.random.structure.dstable(n, params_interactions) ## set interaction matrix
r <- build.normal.gr(n, params_growth_rates)                ## set growth rate
M <- build.rep(A, r, n)                                     ## set payoff matrix for replicator dynamics

# %%
### Run dynamics
y <- lemkeHowson_symmetric(M)  ## get Nash equilibrium of the game
S <- y$subset                  ## Subset of coexisting species
x <- toLV(y$eq, n)[S]          ## equilibrium of LV model
B <- M[S, S]                   ## Final interaction Matrix
v <- r[S]                      ## Final vector of growth rates

length(y$subset)
length(x)
# Out:
# [1] 503
# [1] 503

# %% [markdown]
# ### Compare eigenvalue distribution
#
# Before and after dynamical pruning.

# %%
evals_pruned <- eigen(B, only.values = TRUE)$values  
evals_original  <- eigen(A, only.values = TRUE)$values

Evals_pruned <- data_frame(x = Re(evals_pruned),
                           y = Im(evals_pruned), type = "pruned")
Evals_original <- data_frame(x = Re(evals_original),
                             y = Im(evals_original), type = "original")
Evals <- Evals_pruned %>% bind_rows(Evals_original)

Evals %>% ggplot(aes(x = x, y = y)) + geom_point()  +
    facet_grid(.~type) + theme_bw(base_size = 20) + coord_fixed()
# Out:
# Warning message:
# “`data_frame()` was deprecated in tibble 1.1.0.
# Please use `tibble()` instead.
# This warning is displayed once every 8 hours.
# Call `lifecycle::last_warnings()` to see where this warning was generated.”
# plot without title

# %% [markdown]
# ### Compare distribution of coefficients

# %%
Dist_coeff_o <- data_frame(a = A[upper.tri(A)], type = "original")
Dist_coeff <- data_frame(a = B[upper.tri(B)], type = "pruned")
Dist_coeff <- Dist_coeff %>% bind_rows(Dist_coeff_o)

Dist_coeff %>% ggplot(aes(x = a, fill = type, colour = type)) +
    geom_density(alpha = 0.5) + facet_grid(.~type) + theme_bw(base_size = 20)
# Out:
# plot without title

# %% [markdown]
# ### Compared distribution of growth rates

# %%
# tikzDevice::tikz(file = "r_shift.tex", width=10/2.54, height=5.5/2.54)

Dist_growth_rates <- data_frame(r = v, type = "pruned") %>% bind_rows(data_frame(r = r, type = "original"))

Dist_growth_rates %>% ggplot(aes(x = r, fill = type, colour = type)) +
    geom_density(alpha = 0.5) + facet_grid(.~type) + theme_bw()+
    theme(plot.title = element_text(hjust = 0.5), panel.background = element_rect(fill = "transparent"), # bg of the panel
            plot.background = element_rect(fill = "transparent", color = NA), 
            legend.background = element_rect(fill = "transparent", color = NA)) # bg of the plot
# ggsave("simulations_bin_corr.pdf", arrangeGrob(p1, p2, p3, ncol=3), scale=4, width=12, height=5, units='cm', bg='transparent')
# dev.off()
# Out:
# plot without title

# %% [markdown]
# # Numerical computation of distribution of attractor's sizes
#
# ## Simulations no structure, $r_i$ from normal distribution with mean 0
#
# Expectation distribution is a binomial with $p=\frac{1}{2}$

# %%
# function to replicate LV dynamics a nsim of times, for communities with n species
get_distribution_sizes_attractors <- function(n, nsim,
                                              params_interactions,
                                              params_growth_rates){
    sizes <- map_dbl(1:nsim, function(i){
        A <- build.random.structure.dstable(n, params_interactions)
        r <- build.normal.gr(n, params_growth_rates)
        M <- build.rep(A, r, n)
        y <- lemkeHowson_symmetric(M)
        return (length(y$subset))
    })

    D <- data_frame(n = n, k = sizes, mu = params_interactions$u, sd = params_interactions$sd, gamma = params_growth_rates$u)
    
    ## convert to frequencies, if needed the grouping can be done for all different parameters
    D <- D %>% group_by(k) %>% summarise(count = n()) %>% mutate(freq = count / sum(count)) %>%
        ungroup()

    return (D)
}

# %%
# no structure, different starting number of species n

nsim <- 10000
set.seed(1234430) ## set random seed for simulations

n1 <- 15
attractors15 <- get_distribution_sizes_attractors(n1, nsim,
                                                params_interactions,
                                                params_growth_rates )

n2 <- 5
attractors5 <- get_distribution_sizes_attractors(n2, nsim,
                                                params_interactions,
                                                params_growth_rates )

n3 <- 25
attractors25 <- get_distribution_sizes_attractors(n3, nsim,
                                                params_interactions,
                                                params_growth_rates )

# %%
## Binomal expectation
attractors15 <- attractors15 %>% mutate(expectation = choose(n1, k) *  0.5^n1)
attractors5  <- attractors5  %>% mutate(expectation = choose(n2, k) *  0.5^n2)
attractors25 <- attractors25 %>% mutate(expectation = choose(n3, k) *  0.5^n3)

# %%
# pdf('simulations_bin.pdf', width=12.8/2.54, height=9.6/2.54)
# tikzDevice::tikz(file = "simulations_bin.tex", width=11/2.54, height=5/2.54)

## Plotting
p1 <- attractors5 %>% ggplot(aes(x = k, y = freq)) +
      geom_bar(stat = "identity", alpha = 0.5, colour = "dodgerblue", size=1.2, fill = "deepskyblue") +
      geom_point(aes(y = expectation), shape = 19, size = 1.5, col="royalblue4") + 
      xlab(TeX("$k$")) + ylab(TeX("$P(k|n)$")) + ggtitle(TeX("$n=5$")) + theme_bw(base_size = 20) +
      # xlab("$k$") + ylab("$\\mathcal{P}(k|n)$") + ggtitle("$n=5$") + theme_bw() +
      theme(plot.title = element_text(hjust = 0.5), panel.background = element_rect(fill = "transparent"), # bg of the panel
            plot.background = element_rect(fill = "transparent", color = NA)) # bg of the plot
            

p2 <- attractors15 %>% ggplot(aes(x = k, y = freq)) +
      geom_bar(stat = "identity", alpha = 0.5, colour = "orangered", size=1.2, fill = "tomato") +
      geom_point(aes(y = expectation), shape = 19, size = 1.5, col="firebrick2") + 
      xlab(TeX("$k$")) + ylab("") + ggtitle(TeX("$n=15$")) + theme_bw(base_size = 20) +
      # xlab("$k$") + ylab("") + ggtitle("$n=15$") + theme_bw() +
      theme(plot.title = element_text(hjust = 0.5), panel.background = element_rect(fill = "transparent"), # bg of the panel
            plot.background = element_rect(fill = "transparent", color = NA)) # bg of the plot
     
p3 <- attractors25 %>% ggplot(aes(x = k, y = freq)) +
      geom_bar(stat = "identity", alpha = 0.5, colour = "darkslategray", size=1.2, fill = "darkseagreen2") +
      geom_point(aes(y = expectation), shape = 19, size = 1.5, col="olivedrab") + 
      xlab(TeX("$k$")) + ylab("") + ggtitle(TeX("$n=25$")) + theme_bw(base_size = 20) +
      # xlab("$k$") + ylab("") + ggtitle("$n=25$") + theme_bw() +
      theme(plot.title = element_text(hjust = 0.5), panel.background = element_rect(fill = "transparent"), # bg of the panel
            plot.background = element_rect(fill = "transparent", color = NA)) # bg of the plot
     
grid.arrange(p1, p2, p3, ncol=3)

# ggsave("simulations_bin.pdf", arrangeGrob(p1, p2, p3, ncol=3), scale=4, width=12, height=5, units='cm', bg='transparent')
# dev.off()
# Out:
# plot without title

# %% [markdown]
# ## Simulation with correlation
#
# Sample interaction matrix terms froma bivariate gaussian distribution, with covariance term $\rho$ (``p`` in the ``params_interaction`` function).

# %%
params_interactions <- list(build.structure = build.no.structure, ## completely filled matrix
               build.matrix = build.cor.normal,                   ## normal matrix with correlation
               u = 0,                                             ## mean of interactions
               d = -1,                                            ## original mean diagonal (this may change to ensure stability)
               sd = 1,                                            ## standard deviation of interactions
               p  = 1                                             ## correlation rho
               )
# params_growth_rates <- list(u = 0,                   ## mean of growth rates
#                             sd = 1                   ## sd of growth rates   
#                             )

# %%
n <- 10
nsim <- 10000
set.seed(1234430) ## set random seed for simulations

params_interactions$p <- 0
attractors1 <- get_distribution_sizes_attractors(n, nsim,
                                                params_interactions,
                                                params_growth_rates )

params_interactions$p <- 1
attractors2 <- get_distribution_sizes_attractors(n, nsim,
                                                params_interactions,
                                                params_growth_rates )

params_interactions$p <- -1
attractors3 <- get_distribution_sizes_attractors(n, nsim,
                                                params_interactions,
                                                params_growth_rates )

# %%
## Again binomial expectation
attractors1 <- attractors1 %>% mutate(expectation = choose(n, k) *  0.5^n)
attractors3 <- attractors3 %>% mutate(expectation = choose(n, k) *  0.5^n)
attractors2 <- attractors2 %>% mutate(expectation = choose(n, k) *  0.5^n)

# %%
# tikzDevice::tikz(file = "simulations_bin_corr.tex", width=11/2.54, height=5/2.54)

## Plotting
p1 <- attractors3 %>% ggplot(aes(x = k, y = freq)) +
      geom_bar(stat = "identity", alpha = 0.5, colour = "dodgerblue", size=1.2, fill = "deepskyblue") +
      geom_point(aes(y = expectation), shape = 19, size = 1.5, col="royalblue4") + 
      xlab(TeX("$k$")) + ylab(TeX("$P(k|n)$")) + ggtitle(TeX("$\\rho = -0.5$")) + theme_bw(base_size = 20) +
      # xlab("$k$") + ylab("$\\mathcal{P}(k|n)$") + ggtitle("$\\rho = -0.5$") + theme_bw() +
      theme(plot.title = element_text(hjust = 0.5), panel.background = element_rect(fill = "transparent"), # bg of the panel
            plot.background = element_rect(fill = "transparent", color = NA)) # bg of the plot
            
p2 <- attractors2 %>% ggplot(aes(x = k, y = freq)) +
      geom_bar(stat = "identity", alpha = 0.5, colour = "darkslategray", size=1.2, fill = "darkseagreen2") +
      geom_point(aes(y = expectation), shape = 19, size = 1.5, col="olivedrab") + 
      xlab(TeX("$k$")) + ylab("") + ggtitle(TeX("$\\rho = 0$")) + theme_bw(base_size = 20) +
      # xlab("$k$") + ylab("") + ggtitle("$\\rho = 0$") + theme_bw() +
      theme(plot.title = element_text(hjust = 0.5), panel.background = element_rect(fill = "transparent"), # bg of the panel
            plot.background = element_rect(fill = "transparent", color = NA)) # bg of the plot

p3 <- attractors1 %>% ggplot(aes(x = k, y = freq)) +
      geom_bar(stat = "identity", alpha = 0.5, colour = "orangered", size=1.2, fill = "tomato") +
      geom_point(aes(y = expectation), shape = 19, size = 1.5, col="firebrick2") + 
      xlab(TeX("$k$")) + ylab("") + ggtitle(TeX("$\\rho = 0.5$")) + theme_bw(base_size = 20) +
      # xlab("$k$") + ylab("") + ggtitle("$\\rho = 0.5$") + theme_bw() +
      theme(plot.title = element_text(hjust = 0.5), panel.background = element_rect(fill = "transparent"), # bg of the panel
            plot.background = element_rect(fill = "transparent", color = NA)) # bg of the plot

grid.arrange(p1, p2, p3, ncol=3)

# ggsave("simulations_bin_corr.pdf", arrangeGrob(p1, p2, p3, ncol=3), scale=4, width=12, height=5, units='cm', bg='transparent')
# dev.off()
# Out:
# plot without title

# %% [markdown]
# ## Adding structure
# Combine matrix $A$ with a structure matrix $G$. Growth rates $r_i$ sampled again from normal distribution with mean 0.

# %%
interactions_MF <- list(build.structure = build.fixed.matrix, ## matrix with fixed diagonal structure
                        build.matrix = build.normal,          ## normal matrix 
                        u = 0,                                ## mean of interactions
                        d = -1,                               ## original mean diagonal (this may change to ensure stability)
                        sd = 1                                ## standard deviation of interactions
                        )

interactions_PL <- list(build.structure = build.powerlaw, ## powerlaw matrix
                        build.matrix = build.normal,      ## normal matrix 
                        exponent = 2.5,                   ## exponent for power law correlations
                        c = 0.2,                          ## connectance
                        u = 0,                            ## mean of interactions
                        d = -1,                           ## original mean diagonal (this may change to ensure stability)
                        sd = 1                            ## standard deviation of interactions
                        )

interactions_2B <- list(build.structure = build.2.blocks, ## 2 interacting blocks matrix
                        build.matrix = build.normal,      ## normal matrix 
                        c_between = 0.2,                  ## connectance between the 2 blocks
                        c_within = 0.2,                   ## connectance within each block
                        block_ratio = 0.3,                ## proportion of the 2 blocks
                        u = 0,                            ## mean of interactions
                        d = -1,                           ## original mean diagonal (this may change to ensure stability)
                        sd = 1                            ## standard deviation of interactions
                        )

params_growth_rates <- list(u = 0,                   ## mean of growth rates
                            sd = 1                   ## sd of growth rates   
                            )

n <- 10
nsim <- 10000
set.seed(1234430) ## set random seed for simulations

# %%
attractors_MF <- get_distribution_sizes_attractors(n, nsim,
                                                   interactions_MF,
                                                   params_growth_rates )

# %%
attractors_PL <- get_distribution_sizes_attractors(n, nsim,
                                                   interactions_PL,
                                                   params_growth_rates )

# %%
attractors_2B <- get_distribution_sizes_attractors(n, nsim,
                                                   interactions_2B,
                                                   params_growth_rates )

# %%
## In this case we can get a binomal expectation
attractors_MF <- attractors_MF %>% mutate(expectation = choose(n, k) *  0.5^n)
attractors_PL <- attractors_PL %>% mutate(expectation = choose(n, k) *  0.5^n)
attractors_2B <- attractors_2B %>% mutate(expectation = choose(n, k) *  0.5^n)

# %%
# tikzDevice::tikz(file = "simulations_3_struc.tex", width=11/2.54, height=5/2.54)

## Plotting
p1 <- attractors_MF %>% ggplot(aes(x = k, y = freq)) +
      geom_bar(stat = "identity", alpha = 0.5, colour = "dodgerblue", size=1.2, fill = "deepskyblue") +
      geom_point(aes(y = expectation), shape = 19, size = 1.5, col="royalblue4") + 
      xlab(TeX("$k$")) + ylab(TeX("$P(k|n)$")) + ggtitle(TeX("Fixed matrix")) + theme_bw(base_size = 20) +
      # xlab("$k$") + ylab("$\\mathcal{P}(k|n)$") + ggtitle("Fixed matrix") + theme_bw() +
      theme(plot.title = element_text(hjust = 0.5), panel.background = element_rect(fill = "transparent"), # bg of the panel
            plot.background = element_rect(fill = "transparent", color = NA)) # bg of the plot
            
p2 <- attractors_PL %>% ggplot(aes(x = k, y = freq)) +
      geom_bar(stat = "identity", alpha = 0.5, colour = "darkslategray", size=1.2, fill = "darkseagreen2") +
      geom_point(aes(y = expectation), shape = 19, size = 1.5, col="olivedrab") + 
      xlab(TeX("$k$")) + ylab("") + ggtitle(TeX("Power law")) + theme_bw(base_size = 20) +
      # xlab("$k$") + ylab("") + ggtitle("Power law") + theme_bw() +
      theme(plot.title = element_text(hjust = 0.5), panel.background = element_rect(fill = "transparent"), # bg of the panel
            plot.background = element_rect(fill = "transparent", color = NA)) # bg of the plot

p3 <- attractors_2B %>% ggplot(aes(x = k, y = freq)) +
      geom_bar(stat = "identity", alpha = 0.5, colour = "orangered", size=1.2, fill = "tomato") +
      geom_point(aes(y = expectation), shape = 19, size = 1.5, col="firebrick2") + 
      xlab(TeX("$k$")) + ylab("") + ggtitle(TeX("2 blocks")) + theme_bw(base_size = 20) +
      # xlab("$k$") + ylab("") + ggtitle("2 blocks") + theme_bw() +
      theme(plot.title = element_text(hjust = 0.5), panel.background = element_rect(fill = "transparent"), # bg of the panel
            plot.background = element_rect(fill = "transparent", color = NA)) # bg of the plot

grid.arrange(p1, p2, p3, ncol=3)

# ggsave("simulations_3_struc.pdf", arrangeGrob(p1, p2, p3, ncol=3), scale=4, width=12, height=5, units='cm', bg='transparent')
# dev.off()
# Out:
# plot without title

# %%
# Example of interaction matrices with structure

# tikzDevice::tikz(file = "matrix_3_struc_dstab.tex", width=11/2.54, height=3.5/2.54)
options(repr.plot.width=17, repr.plot.height=5)  #to set graph size
# par(mfrow= c(1,2), mar=c(5, 5, 4, 2), cex=1.5)
set.seed(1234430) ## set random seed for simulations

mat_fixeds <- build.random.structure.dstable(n, interactions_MF)
mat_powerl <- build.random.structure.dstable(n, interactions_PL)
mat_2block <- build.random.structure.dstable(n, interactions_2B)

## Plotting
p1 <- ggplot(melt(mat_fixeds), aes(x=Var1, y=Var2, fill=value)) + geom_tile(colour='black', show.legend = FALSE) +
      scale_y_reverse() + scale_fill_gradient(high = "white", low = "black") + theme_bw() +
      xlab("") + ylab("") + 
      theme(plot.title = element_text(hjust = 0.5), panel.background = element_rect(fill = "transparent"), # bg of the panel
            plot.background = element_rect(fill = "transparent", color = NA), axis.text.y=element_blank(),
            axis.text.x=element_blank(), axis.ticks.x=element_blank(), axis.ticks.y=element_blank()) # bg of the plot

p2 <- ggplot(melt(mat_powerl), aes(x=Var1, y=Var2, fill=value)) + geom_tile(colour='black', show.legend = FALSE) +
      scale_y_reverse() + scale_fill_gradient(high = "white", low = "black") +
      xlab("") + ylab("") + theme_bw() +
      theme(plot.title = element_text(hjust = 0.5), panel.background = element_rect(fill = "transparent"), # bg of the panel
            plot.background = element_rect(fill = "transparent", color = NA), axis.text.y=element_blank(),
            axis.text.x=element_blank(), axis.ticks.x=element_blank(), axis.ticks.y=element_blank()) # bg of the plot

p3 <- ggplot(melt(mat_2block), aes(x=Var1, y=Var2, fill=value)) + geom_tile(colour='black', show.legend = FALSE) +
      scale_y_reverse() + scale_fill_gradient(high = "white", low = "black") +
      xlab("") + ylab("") + theme_bw() +
      theme(plot.title = element_text(hjust = 0.5), panel.background = element_rect(fill = "transparent"), # bg of the panel
            plot.background = element_rect(fill = "transparent", color = NA), axis.text.y=element_blank(),
            axis.text.x=element_blank(), axis.ticks.x=element_blank(), axis.ticks.y=element_blank()) # bg of the plot

grid.arrange(p1, p2, p3, ncol=3)#, nrow=2)

# ggsave("matrix_3_struc_dstab.pdf", arrangeGrob(p1, p2, p3, ncol=3), scale=4, width=12, height=5, units='cm', bg='transparent')
# dev.off()
# Out:
# plot without title

# %%
# Examples of structure matrices

# tikzDevice::tikz(file = "matrix_3_struc.tex", width=11/2.54, height=4/2.54)
# options(repr.plot.width=17, repr.plot.height=5)  #to set graph size
# par(mfrow= c(1,2), mar=c(5, 5, 4, 2), cex=1.5)
set.seed(1234430) ## set random seed for simulations

mat_fixeds <- interactions_MF$build.structure(n, interactions_MF)
mat_powerl <- interactions_PL$build.structure(n, interactions_PL)
mat_2block <- interactions_2B$build.structure(n, interactions_2B)

## Plotting
p1 <- ggplot(melt(mat_fixeds), aes(x=Var1, y=Var2, fill=value)) + geom_tile(colour='black', show.legend = FALSE) +
      scale_y_reverse() + scale_fill_gradient(high = "white", low = "black") +
      xlab("") + ylab("") + ggtitle("Fixed matrix") + theme_bw() +
      theme(plot.title = element_text(hjust = 0.5), panel.background = element_rect(fill = "transparent"), # bg of the panel
            plot.background = element_rect(fill = "transparent", color = NA), axis.text.y=element_blank(),
            axis.text.x=element_blank(), axis.ticks.x=element_blank(), axis.ticks.y=element_blank()) # bg of the plot

p2 <- ggplot(melt(mat_powerl), aes(x=Var1, y=Var2, fill=value)) + geom_tile(colour='black', show.legend = FALSE) +
      scale_y_reverse() + scale_fill_gradient(low = "white", high = "black") +
      xlab("") + ylab("") + ggtitle("Power law") + theme_bw() +
      theme(plot.title = element_text(hjust = 0.5), panel.background = element_rect(fill = "transparent"), # bg of the panel
            plot.background = element_rect(fill = "transparent", color = NA), axis.text.y=element_blank(),
            axis.text.x=element_blank(), axis.ticks.x=element_blank(), axis.ticks.y=element_blank()) # bg of the plot

p3 <- ggplot(melt(mat_2block), aes(x=Var1, y=Var2, fill=value)) + geom_tile(colour='black', show.legend = FALSE) +
      scale_y_reverse() + scale_fill_gradient(low = "white", high = "black") +
      xlab("") + ylab("") + ggtitle("2 blocks") + theme_bw() + 
      theme(plot.title = element_text(hjust = 0.5), panel.background = element_rect(fill = "transparent"), # bg of the panel
            plot.background = element_rect(fill = "transparent", color = NA), axis.text.y=element_blank(),
            axis.text.x=element_blank(), axis.ticks.x=element_blank(), axis.ticks.y=element_blank()) # bg of the plot

grid.arrange(p1, p2, p3, ncol=3)#, nrow=2)

# ggsave("matrix_3_struc.pdf", arrangeGrob(p1, p2, p3, ncol=3), scale=4, width=12, height=5, units='cm', bg='transparent')
# dev.off()
# Out:
# plot without title

# %%
interactions_BP <- list(build.structure = build.full.bipartite, ## modular matrix
                        build.matrix = build.normal,            ## normal matrix 
                        c = 0.2,                                ## connectance
                        block_ratio = 0.3,                      ## proportion of the 2 blocks
                        c_ratio = 0.2,                          ## ratio of the connectance within and among blocks
                        u = 0,                                  ## mean of interactions
                        d = -1,                                 ## original mean diagonal (this may change to ensure stability)
                        sd = 1                                  ## standard deviation of interactions
                        )

interactions_MD <- list(build.structure = build.full.inblocks, ## modular matrix
                        build.matrix = build.normal,           ## normal matrix 
                        c = 0.2,                               ## connectance
                        block_ratio = 0.3,                     ## proportion of the 2 blocks
                        c_ratio = 2,                           ## ratio of the connectance within and among blocks
                        u = 0,                                 ## mean of interactions
                        d = -1,                                ## original mean diagonal (this may change to ensure stability)
                        sd = 1                                 ## standard deviation of interactions
                        )

interactions_ER <- list(build.structure = build.random.structure, ## Erdos-Renyi random graph structure
                        build.matrix = build.normal,              ## normal matrix 
                        c = 0.2,                                  ## connectance
                        u = 0,                                    ## mean of interactions
                        d = -1,                                   ## original mean diagonal (this may change to ensure stability)
                        sd = 1                                    ## standard deviation of interactions
                        )

# %%
# Other examples of structure matrices - for support slides

# tikzDevice::tikz(file = "matrix_3_struc_supp.tex", width=11/2.54, height=4/2.54)
# options(repr.plot.width=17, repr.plot.height=5)  #to set graph size
# par(mfrow= c(1,2), mar=c(5, 5, 4, 2), cex=1.5)

set.seed(1234430) ## set random seed for simulations
mat_random <- interactions_ER$build.structure(n, interactions_ER)
mat_modula <- interactions_MD$build.structure(n, interactions_MD)
mat_bipart <- interactions_BP$build.structure(n, interactions_BP)

## Plotting
p1 <- ggplot(melt(mat_random), aes(x=Var1, y=Var2, fill=value)) + geom_tile(colour='black', show.legend = FALSE) +
      scale_y_reverse() + scale_fill_gradient(low = "white", high = "black") +
      xlab("") + ylab("") + ggtitle("ER graph") + theme_bw() +
      theme(plot.title = element_text(hjust = 0.5), panel.background = element_rect(fill = "transparent"), # bg of the panel
            plot.background = element_rect(fill = "transparent", color = NA), axis.text.y=element_blank(),
            axis.text.x=element_blank(), axis.ticks.x=element_blank(), axis.ticks.y=element_blank()) # bg of the plot

p2 <- ggplot(melt(mat_modula), aes(x=Var1, y=Var2, fill=value)) + geom_tile(colour='black', show.legend = FALSE) +
      scale_y_reverse() + scale_fill_gradient(low = "white", high = "black") +
      xlab("") + ylab("") + ggtitle("Modular") + theme_bw() +
      theme(plot.title = element_text(hjust = 0.5), panel.background = element_rect(fill = "transparent"), # bg of the panel
            plot.background = element_rect(fill = "transparent", color = NA), axis.text.y=element_blank(),
            axis.text.x=element_blank(), axis.ticks.x=element_blank(), axis.ticks.y=element_blank()) # bg of the plot

p3 <- ggplot(melt(mat_bipart), aes(x=Var1, y=Var2, fill=value)) + geom_tile(colour='black', show.legend = FALSE) +
      scale_y_reverse() + scale_fill_gradient(low = "white", high = "black") +
      xlab("") + ylab("") + ggtitle("Bipartite") + theme_bw() + 
      theme(plot.title = element_text(hjust = 0.5), panel.background = element_rect(fill = "transparent"), # bg of the panel
            plot.background = element_rect(fill = "transparent", color = NA), axis.text.y=element_blank(),
            axis.text.x=element_blank(), axis.ticks.x=element_blank(), axis.ticks.y=element_blank()) # bg of the plot

grid.arrange(p1, p2, p3, ncol=3)#, nrow=2)

# ggsave("matrix_3_struc.pdf", arrangeGrob(p1, p2, p3, ncol=3), scale=4, width=12, height=5, units='cm', bg='transparent')
# dev.off()
# Out:
# plot without title

# %% [markdown]
# ## Mean $\neq 0$
#
# Sample growth rates from a gaussian distribution with non-zero mean. Fixed interaction matrix (interacting competitors model).

# %%
interactions_FX <- list(build.structure = build.fixed.matrix, 
                        build.matrix = build.no.structure, 
                        u = -0.5,                             ## off-diagonal terms
                        d = -1                                ## diagonal terms
                        )

params_gr1 <- list(u = 1,                   ## mean of growth rates
                   sd = 1                   ## sd of growth rates   
                   )

params_gr2 <- list(u = 2,                   ## mean of growth rates
                   sd = 1                   ## sd of growth rates   
                   )

params_gr5 <- list(u = 0.5,                 ## mean of growth rates
                   sd = 1                   ## sd of growth rates   
                   )

n <- 15
nsim <- 10000
set.seed(1234430) ## set random seed for simulations

# %%
attractors_1 <- get_distribution_sizes_attractors(n, nsim, interactions_FX, params_gr1)
attractors_2 <- get_distribution_sizes_attractors(n, nsim, interactions_FX, params_gr2)
attractors_5 <- get_distribution_sizes_attractors(n, nsim, interactions_FX, params_gr5)

# %%
attractors_1 <- attractors_1 %>% mutate(expectation = choose(n, k) * (0.5)^n)
attractors_2 <- attractors_2 %>% mutate(expectation = choose(n, k) * (0.5)^n)
attractors_5 <- attractors_5 %>% mutate(expectation = choose(n, k) * (0.5)^n)

# %%
# tikzDevice::tikz(file = "simulations_nonzero.tex", width=11/2.54, height=5/2.54)

## Plotting
p1 <- attractors_5 %>% ggplot(aes(x = k, y = freq)) +
      geom_bar(stat = "identity", alpha = 0.5, colour = "dodgerblue", size=1.2, fill = "deepskyblue") +
      geom_point(aes(y = expectation), shape = 19, size = 1.5, col="royalblue4") + 
      xlab(TeX("$k$")) + ylab(TeX("$P(k|n)$")) + ggtitle(TeX("Fixed matrix")) + theme_bw(base_size = 20) +
      # xlab("$k$") + ylab("$\\mathcal{P}(k|n)$") + ggtitle("$\\gamma = \\frac{1}{2}$") + theme_bw() +
      theme(plot.title = element_text(hjust = 0.5), panel.background = element_rect(fill = "transparent"), # bg of the panel
            plot.background = element_rect(fill = "transparent", color = NA)) # bg of the plot
            
p2 <- attractors_1 %>% ggplot(aes(x = k, y = freq)) +
      geom_bar(stat = "identity", alpha = 0.5, colour = "darkslategray", size=1.2, fill = "darkseagreen2") +
      geom_point(aes(y = expectation), shape = 19, size = 1.5, col="olivedrab") + 
      xlab(TeX("$k$")) + ylab("") + ggtitle(TeX("Power law")) + theme_bw(base_size = 20) +
      # xlab("$k$") + ylab("") + ggtitle("$\\gamma = 1$") + theme_bw() +
      theme(plot.title = element_text(hjust = 0.5), panel.background = element_rect(fill = "transparent"), # bg of the panel
            plot.background = element_rect(fill = "transparent", color = NA)) # bg of the plot

p3 <- attractors_2 %>% ggplot(aes(x = k, y = freq)) +
      geom_bar(stat = "identity", alpha = 0.5, colour = "orangered", size=1.2, fill = "tomato") +
      geom_point(aes(y = expectation), shape = 19, size = 1.5, col="firebrick2") + 
      xlab(TeX("$k$")) + ylab("") + ggtitle(TeX("2 blocks")) + theme_bw(base_size = 20) +
      # xlab("$k$") + ylab("") + ggtitle("$\\gamma = 2$") + theme_bw() +
      theme(plot.title = element_text(hjust = 0.5), panel.background = element_rect(fill = "transparent"), # bg of the panel
            plot.background = element_rect(fill = "transparent", color = NA)) # bg of the plot

grid.arrange(p1, p2, p3, ncol=3)

# ggsave("simulations_3_struc.pdf", arrangeGrob(p1, p2, p3, ncol=3), scale=4, width=12, height=5, units='cm', bg='transparent')
# dev.off()
# Out:
# plot without title

# %% [markdown]
# ## Analitical computations for mode of new distribution

# %%
# support functions
phiinv <- function(q){ 
  supp <- 2*q -1
  supp <- erfinv(supp)
  return(sqrt(2)*supp)
}

# relationship between q, gamma, u
trasc_eqn <- function(q, gamma){
  supp <- exp(-(phiinv(1-q)^2)/2)
  supp <- supp - sqrt(2*pi)*q*phiinv(1-q)
  supp <- supp / (sqrt(2*pi))
  supp <- supp/(gamma + phiinv(1-q))

  return(supp)
}

# root finding function
uniroot.all <- function (f, interval, lower= min(interval),
        upper= max(interval), tol= .Machine$double.eps^0.2,
        maxiter= 1000, trace = 0, n = 100, ... ) {

## error checking as in uniroot...
  if (!missing(interval) && length(interval) != 2)
     stop("'interval' must be a vector of length 2")
  if (!is.numeric(lower) || !is.numeric(upper) || lower >=
     upper)
    stop("lower < upper  is not fulfilled")
 
## subdivide interval in n subintervals and estimate the function values
  xseq <- seq(lower,upper,len=n+1)
  mod  <- f(xseq,...)

## some function values may already be 0
  Equi <- xseq[which(mod==0)]

  ss   <- mod[1:n]*mod[2:(n+1)]  # interval where functionvalues change sign
  ii   <- which(ss<0)

  for (i in ii)
    Equi <- c(Equi, uniroot(f,lower=xseq[i],upper=xseq[i+1], maxiter = maxiter, tol = tol, 
               trace = trace, ...)$root)

  return(Equi)
}

# %%
# set parameter space
gammas <- seq(0.01,1.5, length.out = 50)
log2us <- seq(-3,1, length.out = 50)

us <- 2^log2us

# %%
# compute expectation values by inverting numerically the q, gamma, u relationship
qstars <-  matrix(, nrow = length(gammas), ncol = length(us))

for(i in seq(1, length(gammas))){
   for(j in seq(1, length(us))){
     find_q <- function(q){us[j] - trasc_eqn(q, gammas[i])}

     qstars[i, j] <- uniroot.all(find_q, lower=0.1, upper=0.9)[1]
  }  
 }

# %%
qstars.df <- as.data.frame(qstars) 

colnames(qstars) <- log2us
rownames(qstars) <- gammas
# us.df %>% as.data.frame() %>%  rownames_to_column("$q*{\\star}$") %>%
  # pivot_longer(-c(f_id), names_to = "samples", values_to = "counts")
qstars.plot = melt(qstars)
colnames(qstars.plot)[3] <- "mode"

# boh = qstars.plot
# boh %>% filter(mode > 0.495 & mode< 0.505, Var1>0.8 & Var1<1.2)
head(qstars.plot)
# Out:
#   Var1       Var2 mode
# 1 0.01000000 -3   0.1955182
# 2 0.04040816 -3   0.1987485
# 3 0.07081633 -3   0.2020354
# 4 0.10122449 -3   0.2053203
# 5 0.13163265 -3   0.2085676
# 6 0.16204082 -3   0.2120000

# %%
# tikzDevice::tikz(file = "mode_3d.tex", width=6.5/2.54, height=7.5/2.54)
options(repr.plot.width=6, repr.plot.height=7)  #to set graph size

ggplot(qstars.plot, aes(x=Var2, y=Var1, fill=mode)) + #, aes(x=qstar, y=gammas, fill=value) ) + 
  # scale_fill_gradientn(colours = "Blue-Red 3") +
  # geom_raster(fill=density)+
  # stat_contour_filled() +
  geom_tile()+
  scale_fill_distiller(palette= "RdBu") +
  # stat_density_2d(aes(fill = ..density..), geom = "raster", contour = FALSE) +
  scale_x_continuous(expand = c(0, 0)) +
  scale_y_continuous(expand = c(0, 0))  +
  # ylab("$\\gamma$") + xlab("$\\log_{2}(u)$") + theme_bw() +
  ylab(TeX("$\\gamma$")) + xlab(TeX("$\\log_{2}(u)$")) + theme_bw(base_size = 20) +
  geom_contour(aes(z = mode), breaks = 0.5, col = 'black') +
  theme(plot.title = element_text(hjust = 0.5), panel.background = element_rect(fill = "transparent"), # bg of the panel
        plot.background = element_rect(fill = "transparent", color = NA), # bg of the plot
        legend.background=element_rect(fill = "transparent")
  )

# ggsave("mode_3d.pdf", width=6.5, height=7.5, units='cm', bg='transparent')
# dev.off()
# Out:
# plot without title

# %% [markdown]
# ## Computing the expectation value
#
# Some trials in deriving the expected distribution.

# %%
## Define phi, phiinv for complex values
phicomplex <- function(z){
  y <- 0.5+ 0.5*(erfz(z/sqrt(2)))
  return(y)
  }

phiinv <- function(q){
  supp <- 2*q -1
  supp <- erfinv(Mod(supp))
  return(sqrt(2)*supp)
}

# function for P({S}_k | n)
p_sk_n <-function(k, n, gamma, alpha, mu){
  
  v <- gamma*(alpha-mu)/(alpha-mu+k*mu)
  s <- alpha/mu -1
  
  exp_term <- function(z){
              supp <- (n-k)*log(z) - 0.5*phiinv(z)*(2*v*(k+s)+phiinv(z)*(k - 1 + 2*s))
              supp <- exp(supp)
              return(supp)
  }

  # exp_term <- (n-k)*log(z) - 0.5*phiinv(z)*(2*v*(k+s)+phiinv(z)*(k - 1 + 2*s))
  # exp_term <- exp(exp_term)
  # print(exp_term)
  npoint <- 10000

  tj <- seq(-30, 30, length.out=npoint)
  sj <- rep(0, npoint)
  mask <- rep(0, npoint)
  
  # w <- -s*(phiinv(a)+v)-k*v

  itj <- complex(real=0, imaginary = tj)
  
  f <- exp(- 0.5*k*(tj^2))*(1-phicomplex(itj))^k
  
  # print(f[1:4])
  for(j in seq(1,length(f))){
    sj[j] <- (-1)^(j+1)
  }
  
  f <- sj*f
  # print(f[1:4])
  # print(length(f))
  D <- fft(f)
  # print(D[1:2])
  # print(D)
  fhat <- 1/npoint*D
  for(k in seq(1,length(fhat))){
    mask[k] <- (-1)^(k - 1 - npoint/2)
  }
  # print(fhat[1:2])
  # print(mask)
  fhat <- fhat*mask
  
  # plot(seq(0,1,length.out=npoint), fhat, 'l')
  
  fft_func <- approxfun(tj, fhat)
  aaa <- -s*(phiinv(seq(0,1,length.out = npoint))+v)-k*v
  print(aaa)
  # print(fft_func())
  # print(-s*(phiinv(Re(z))+v)-k*v)
  # plot(seq(0,1,length.out = npoint), Mod(fft_func(tj)))
  p_func <- function(z){exp_term(z) * fft_func(-s*(phiinv(z)+v)-k*v)}
  
  # print(fft_func(-s*(phiinv(Re(test))+v)-k*v))

  normaliz <- (k+s)/sqrt(2*pi)
  # print(normaliz)
  # print(exp_term)
  # print(p_func(0.5))
  test <- seq(0,1,length.out = npoint)
  # plot(test, p_func(test))
  
  p <- integrate(p_func, lower=1e-6, upper=1-1e-6)$value
  
  return(p*normaliz)

}

# p_sk_n(3,15,1,-1, -0.5)*choose(15,3)

# %%
gamss <- c(1, 2, 0.5)
u <- -2/15
n <- 15

# gamss[2]
find_q1 <- function(q){u - trasc_eqn(q, gamss[1])}
mode_1 <- uniroot.all(find_q1, lower=0.1, upper=0.9)

find_q2 <- function(q){u - trasc_eqn(q, gamss[2])}
mode_2 <- uniroot.all(find_q2, lower=0.1, upper=0.9)

find_q5 <- function(q){u - trasc_eqn(q, gamss[3])}
mode_5 <- uniroot.all(find_q5, lower=0.1, upper=0.9)

mode_1 <- n*mode_1
mode_2 <- n*mode_2
mode_5 <- n*mode_5
# Out:
# [1] 11.40691
# [1] 11.9462
# [1] 11.10555
